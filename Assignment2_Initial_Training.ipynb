# %% [markdown]
# # Assignment 2 CNN
# **Ruyu Liu**
# **a1882974**

# %%
# import libraries
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader,TensorDataset
import copy
from sklearn.model_selection import train_test_split


# for importing data
import os
import torchvision
from torchvision import datasets, transforms, models
from torchvision.utils import make_grid

import matplotlib.pyplot as plt
from IPython import display
display.set_matplotlib_formats('svg')
# Out:
# /var/folders/gx/pwy0byr15pq8m62vhfygrw8w0000gn/T/ipykernel_57640/2870729131.py:20: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   display.set_matplotlib_formats('svg')

# %%
# TRANSFORMATIONS
transform = transforms.Compose([
    transforms.Resize(100),
    transforms.CenterCrop(100),
    transforms.ToTensor(), # normalizes to range [0,1]
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225]) # further normalization
])

# %%
# LOAD THE DATA
root = '../Data/Fruit360/fruits-360_dataset/fruits-360/'

train_data = datasets.ImageFolder(os.path.join(root, 'Training'), transform=transform)
test_data = datasets.ImageFolder(os.path.join(root, 'Test'), transform=transform)

torch.manual_seed(42)
# BATCHSIZE = 100
train_loader = DataLoader(train_data, batch_size=100, shuffle=True)
test_loader = DataLoader(test_data, batch_size=100, shuffle=True)

class_names = train_data.classes

print(f'Training images available: {len(train_data)}')
print(f'Testing images available:  {len(test_data)}')
print(f'Class types available:  {len(class_names)}')
# Out:
# Training images available: 67692
# Testing images available:  22688
# Class types available:  131

# %%
# IMAGE DISPLAY

for images, labels in train_loader:
    break

im = make_grid(images, nrow = 10)

inv_normalize = transforms.Normalize(
    mean = [-0.485/0.229, -0.456/0.224, -0.406/0.225],
    std = [1/0.229, 1/0.224, 1/0.225]
)
im_inv = inv_normalize(im)

plt.figure(figsize=(12,4))
plt.imshow(np.transpose(im_inv.numpy(),(1,2,0)))
plt.savefig('DataImage_Display.png')

# %% [markdown]
# ## Basic CNN Initial Training and Testing

# %%
class basicCNN(nn.Module):
    def __init__(self):
        super().__init__()

        ### -------------- feature map layers -------------- ###
        # first convolution layer
        self.conv1  = nn.Conv2d(3,32,3,stride=1)
        self.bnorm1 = nn.BatchNorm2d(32) # input the number of channels in this layer

        # second convolution layer
        self.conv2  = nn.Conv2d(32,32,3,stride=1)
        self.bnorm2 = nn.BatchNorm2d(32) # input the number of channels in this layer
      
        # third convolution layer
        self.conv3  = nn.Conv2d(32,64,3,stride=1)
        self.bnorm3 = nn.BatchNorm2d(64) # input the number of channels in this layer


        ### -------------- linear decision layers -------------- ###
        self.fc1 = nn.Linear(10*10*64,1024)
        self.fc2 = nn.Linear(1024,512)
        self.fc3 = nn.Linear(512,131)


    def forward(self,x):
      
        # first block: convolution -> maxpool -> batchnorm -> relu
        x = F.max_pool2d(self.conv1(x),2)
        x = F.relu(self.bnorm1(x))

        # second block: convolution -> maxpool -> batchnorm -> relu
        x = F.max_pool2d(self.conv2(x),2)
        x = F.relu(self.bnorm2(x))

        # third block: convolution -> maxpool -> batchnorm -> relu
        x = F.max_pool2d(self.conv3(x),2)
        x = F.relu(self.bnorm3(x))

        # reshape for linear layer
        x = x.view(-1,10*10*64)
      
        # linear layers
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)

        return F.log_softmax(x, dim=1)

# %%
# create the model instance
cnn = basicCNN()
lossfun = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(cnn.parameters(),lr=0.01,momentum=.9)

# %%
import time
start_time = time.time()

numepochs = 10

# initialize losses
CtrainLoss = torch.zeros(numepochs)
CtestLoss  = torch.zeros(numepochs)
CtrainAcc  = torch.zeros(numepochs)
CtestAcc   = torch.zeros(numepochs)
Ctrain_correct = []
Ctest_correct = []


# loop over epochs
for epochi in range(numepochs):
    
    # loop over training data batches
    cnn.train() # switch to train mode
    batchLoss = []
    batchAcc  = []
    Ctrn_corr = 0
    
    for b, (X,y) in enumerate(train_loader):
        b += 1
        # forward pass and loss
        yHat = cnn(X)
        loss = lossfun(yHat,y)

        # backprop
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # loss and accuracy from this batch
        batchLoss.append(loss.item())
        batchAcc.append( torch.mean((torch.argmax(yHat,axis=1) == y).float()).item() )
        batch_corr = (torch.argmax(yHat,axis=1) == y).sum()
        Ctrn_corr += batch_corr 
        
        # Print interim results
        if b%50 == 0:
            print(f'epoch: {epochi:2}  batch: {b:4} loss: {loss.item():10.8f} train accuracy: {Ctrn_corr.item()*100/(100*b):7.3f}%')

      # end of batch loop...

    # and get average losses and accuracies across the batches
    CtrainLoss[epochi] = np.mean(batchLoss)
    CtrainAcc[epochi]  = 100*np.mean(batchAcc)

    
    #### test performance (here done in batches!)
    cnn.eval() # switch to test mode
    batchAcc  = []
    batchLoss = []
    Ctst_corr = 0
    
    for b,(X,y) in enumerate(test_loader):
        # forward pass and loss
        with torch.no_grad():
            yHat = cnn(X)
            loss = lossfun(yHat,y)
            Ctst_corr += (torch.argmax(yHat,axis=1) == y).sum()
            
        # loss and accuracy from this batch
        batchLoss.append(loss.item())
        batchAcc.append( torch.mean((torch.argmax(yHat,axis=1) == y).float()).item() )
    # end of batch loop...

    
    # and get average losses and accuracies across the batches
    CtestLoss[epochi] = np.mean(batchLoss)
    CtestAcc[epochi]  = 100*np.mean(batchAcc)

    # print out a status update
    print(f'Finished epoch {epochi+1}/{numepochs}. Test accuracy = {CtestAcc[epochi]:.2f}%')

print(f'\nDuration: {time.time() - start_time:.0f} seconds') # print the time elapsed
# Out:
# epoch:  0  batch:   50 loss: 2.80482483 train accuracy:  14.200%
# epoch:  0  batch:  100 loss: 1.01554143 train accuracy:  35.280%
# epoch:  0  batch:  150 loss: 0.49658653 train accuracy:  50.700%
# epoch:  0  batch:  200 loss: 0.31866756 train accuracy:  60.590%
# epoch:  0  batch:  250 loss: 0.12873699 train accuracy:  67.284%
# epoch:  0  batch:  300 loss: 0.10190260 train accuracy:  72.130%
# epoch:  0  batch:  350 loss: 0.14084204 train accuracy:  75.671%
# epoch:  0  batch:  400 loss: 0.04188085 train accuracy:  78.478%
# epoch:  0  batch:  450 loss: 0.10447793 train accuracy:  80.636%
# epoch:  0  batch:  500 loss: 0.04992328 train accuracy:  82.430%
# epoch:  0  batch:  550 loss: 0.02439370 train accuracy:  83.940%
# epoch:  0  batch:  600 loss: 0.04784936 train accuracy:  85.227%
# epoch:  0  batch:  650 loss: 0.06661486 train accuracy:  86.325%
# Finished epoch 1/10. Test accuracy = 94.85%
# epoch:  1  batch:   50 loss: 0.02458448 train accuracy:  99.340%
# epoch:  1  batch:  100 loss: 0.00494086 train accuracy:  99.530%
# epoch:  1  batch:  150 loss: 0.00803720 train accuracy:  99.653%
# epoch:  1  batch:  200 loss: 0.00868770 train accuracy:  99.640%
# epoch:  1  batch:  250 loss: 0.00658345 train accuracy:  99.636%
# epoch:  1  batch:  300 loss: 0.01266038 train accuracy:  99.630%
# epoch:  1  batch:  350 loss: 0.01585587 train accuracy:  99.583%
# epoch:  1  batch:  400 loss: 0.00496317 train accuracy:  99.590%
# epoch:  1  batch:  450 loss: 0.00394746 train accuracy:  99.620%
# epoch:  1  batch:  500 loss: 0.01639035 train accuracy:  99.628%
# epoch:  1  batch:  550 loss: 0.00195194 train accuracy:  99.653%
# epoch:  1  batch:  600 loss: 0.00572786 train accuracy:  99.680%
# epoch:  1  batch:  650 loss: 0.00184117 train accuracy:  99.705%
# Finished epoch 2/10. Test accuracy = 98.00%
# epoch:  2  batch:   50 loss: 0.00254436 train accuracy:  99.880%
# epoch:  2  batch:  100 loss: 0.01879607 train accuracy:  99.840%
# epoch:  2  batch:  150 loss: 0.00198748 train accuracy:  99.840%
# epoch:  2  batch:  200 loss: 0.01608178 train accuracy:  99.865%
# epoch:  2  batch:  250 loss: 0.01824173 train accuracy:  99.876%
# epoch:  2  batch:  300 loss: 0.00274705 train accuracy:  99.890%
# epoch:  2  batch:  350 loss: 0.00118216 train accuracy:  99.897%
# epoch:  2  batch:  400 loss: 0.00090578 train accuracy:  99.910%
# epoch:  2  batch:  450 loss: 0.00131919 train accuracy:  99.920%
# epoch:  2  batch:  500 loss: 0.00042865 train accuracy:  99.922%
# epoch:  2  batch:  550 loss: 0.03297572 train accuracy:  99.927%
# epoch:  2  batch:  600 loss: 0.00232884 train accuracy:  99.918%
# epoch:  2  batch:  650 loss: 0.00152781 train accuracy:  99.915%
# Finished epoch 3/10. Test accuracy = 97.97%
# epoch:  3  batch:   50 loss: 0.00358811 train accuracy:  99.820%
# epoch:  3  batch:  100 loss: 0.00135344 train accuracy:  99.780%
# epoch:  3  batch:  150 loss: 0.00166498 train accuracy:  99.820%
# epoch:  3  batch:  200 loss: 0.00065670 train accuracy:  99.865%
# epoch:  3  batch:  250 loss: 0.00062776 train accuracy:  99.892%
# epoch:  3  batch:  300 loss: 0.00059779 train accuracy:  99.910%
# epoch:  3  batch:  350 loss: 0.00057682 train accuracy:  99.923%
# epoch:  3  batch:  400 loss: 0.00060316 train accuracy:  99.933%
# epoch:  3  batch:  450 loss: 0.00052577 train accuracy:  99.936%
# epoch:  3  batch:  500 loss: 0.00042095 train accuracy:  99.942%
# epoch:  3  batch:  550 loss: 0.00074987 train accuracy:  99.947%
# epoch:  3  batch:  600 loss: 0.00112756 train accuracy:  99.952%
# epoch:  3  batch:  650 loss: 0.00216112 train accuracy:  99.943%
# Finished epoch 4/10. Test accuracy = 98.66%
# epoch:  4  batch:   50 loss: 0.00093326 train accuracy: 100.000%
# epoch:  4  batch:  100 loss: 0.00102753 train accuracy:  99.980%
# epoch:  4  batch:  150 loss: 0.00161977 train accuracy:  99.987%
# epoch:  4  batch:  200 loss: 0.00033707 train accuracy:  99.990%
# epoch:  4  batch:  250 loss: 0.00047171 train accuracy:  99.992%
# epoch:  4  batch:  300 loss: 0.00048169 train accuracy:  99.987%
# epoch:  4  batch:  350 loss: 0.00099254 train accuracy:  99.989%
# epoch:  4  batch:  400 loss: 0.00038919 train accuracy:  99.990%
# epoch:  4  batch:  450 loss: 0.00623307 train accuracy:  99.982%
# epoch:  4  batch:  500 loss: 0.00136247 train accuracy:  99.982%
# epoch:  4  batch:  550 loss: 0.00051556 train accuracy:  99.984%
# epoch:  4  batch:  600 loss: 0.00062921 train accuracy:  99.985%
# epoch:  4  batch:  650 loss: 0.00354160 train accuracy:  99.985%
# Finished epoch 5/10. Test accuracy = 98.49%
# epoch:  5  batch:   50 loss: 0.00037037 train accuracy: 100.000%
# epoch:  5  batch:  100 loss: 0.00062609 train accuracy: 100.000%
# epoch:  5  batch:  150 loss: 0.00027418 train accuracy: 100.000%
# epoch:  5  batch:  200 loss: 0.00598908 train accuracy:  99.965%
# epoch:  5  batch:  250 loss: 0.00721641 train accuracy:  99.940%
# epoch:  5  batch:  300 loss: 0.00179698 train accuracy:  99.930%
# epoch:  5  batch:  350 loss: 0.00477073 train accuracy:  99.917%
# epoch:  5  batch:  400 loss: 0.00051361 train accuracy:  99.925%
# epoch:  5  batch:  450 loss: 0.00061031 train accuracy:  99.933%
# epoch:  5  batch:  500 loss: 0.00033939 train accuracy:  99.938%
# epoch:  5  batch:  550 loss: 0.00038355 train accuracy:  99.944%
# epoch:  5  batch:  600 loss: 0.00050783 train accuracy:  99.948%
# epoch:  5  batch:  650 loss: 0.00032531 train accuracy:  99.946%
# Finished epoch 6/10. Test accuracy = 98.16%
# epoch:  6  batch:   50 loss: 0.00073001 train accuracy: 100.000%
# epoch:  6  batch:  100 loss: 0.00059005 train accuracy: 100.000%
# epoch:  6  batch:  150 loss: 0.00051380 train accuracy: 100.000%
# epoch:  6  batch:  200 loss: 0.00041594 train accuracy: 100.000%
# epoch:  6  batch:  250 loss: 0.00213482 train accuracy: 100.000%
# epoch:  6  batch:  300 loss: 0.00052960 train accuracy:  99.997%
# epoch:  6  batch:  350 loss: 0.00639541 train accuracy:  99.994%
# epoch:  6  batch:  400 loss: 0.00025638 train accuracy:  99.995%
# epoch:  6  batch:  450 loss: 0.00019792 train accuracy:  99.991%
# epoch:  6  batch:  500 loss: 0.00051804 train accuracy:  99.992%
# epoch:  6  batch:  550 loss: 0.00058445 train accuracy:  99.989%
# epoch:  6  batch:  600 loss: 0.00025447 train accuracy:  99.988%
# epoch:  6  batch:  650 loss: 0.00040456 train accuracy:  99.989%
# Finished epoch 7/10. Test accuracy = 98.55%
# epoch:  7  batch:   50 loss: 0.00925681 train accuracy:  99.940%
# epoch:  7  batch:  100 loss: 0.00031101 train accuracy:  99.960%
# epoch:  7  batch:  150 loss: 0.00058397 train accuracy:  99.967%
# epoch:  7  batch:  200 loss: 0.00025137 train accuracy:  99.975%
# epoch:  7  batch:  250 loss: 0.00049761 train accuracy:  99.980%
# epoch:  7  batch:  300 loss: 0.00020128 train accuracy:  99.983%
# epoch:  7  batch:  350 loss: 0.00025774 train accuracy:  99.986%
# epoch:  7  batch:  400 loss: 0.00032587 train accuracy:  99.987%
# epoch:  7  batch:  450 loss: 0.00091434 train accuracy:  99.987%
# epoch:  7  batch:  500 loss: 0.00051421 train accuracy:  99.988%
# epoch:  7  batch:  550 loss: 0.00048110 train accuracy:  99.989%
# epoch:  7  batch:  600 loss: 0.00080253 train accuracy:  99.990%
# epoch:  7  batch:  650 loss: 0.00023414 train accuracy:  99.991%
# Finished epoch 8/10. Test accuracy = 98.89%
# epoch:  8  batch:   50 loss: 0.00112777 train accuracy:  99.980%
# epoch:  8  batch:  100 loss: 0.00053931 train accuracy:  99.990%
# epoch:  8  batch:  150 loss: 0.00033707 train accuracy:  99.993%
# epoch:  8  batch:  200 loss: 0.00027167 train accuracy:  99.995%
# epoch:  8  batch:  250 loss: 0.00096189 train accuracy:  99.988%
# epoch:  8  batch:  300 loss: 0.00051253 train accuracy:  99.987%
# epoch:  8  batch:  350 loss: 0.00030145 train accuracy:  99.977%
# epoch:  8  batch:  400 loss: 0.00023476 train accuracy:  99.980%
# epoch:  8  batch:  450 loss: 0.00033125 train accuracy:  99.978%
# epoch:  8  batch:  500 loss: 0.00153543 train accuracy:  99.962%
# epoch:  8  batch:  550 loss: 0.00030135 train accuracy:  99.951%
# epoch:  8  batch:  600 loss: 0.00027195 train accuracy:  99.953%
# epoch:  8  batch:  650 loss: 0.00128827 train accuracy:  99.957%
# Finished epoch 9/10. Test accuracy = 98.92%
# epoch:  9  batch:   50 loss: 0.00036072 train accuracy: 100.000%
# epoch:  9  batch:  100 loss: 0.00034163 train accuracy:  99.990%
# epoch:  9  batch:  150 loss: 0.00109051 train accuracy:  99.993%
# epoch:  9  batch:  200 loss: 0.00161459 train accuracy:  99.995%
# epoch:  9  batch:  250 loss: 0.00126348 train accuracy:  99.996%
# epoch:  9  batch:  300 loss: 0.00020863 train accuracy:  99.997%
# epoch:  9  batch:  350 loss: 0.00031396 train accuracy:  99.997%
# epoch:  9  batch:  400 loss: 0.00013867 train accuracy:  99.998%
# epoch:  9  batch:  450 loss: 0.00036293 train accuracy:  99.998%
# epoch:  9  batch:  500 loss: 0.00033886 train accuracy:  99.998%
# epoch:  9  batch:  550 loss: 0.00138696 train accuracy:  99.998%
# epoch:  9  batch:  600 loss: 0.00011197 train accuracy:  99.998%
# epoch:  9  batch:  650 loss: 0.00017840 train accuracy:  99.998%
# Finished epoch 10/10. Test accuracy = 98.86%
#
# Duration: 5503 seconds

# %%
torch.save(cnn.state_dict(), 'FRUITS-CNN-Model.pt')

# %%
fig,ax = plt.subplots(1,2,figsize=(16,5))

ax[0].plot(CtrainLoss,'s-',label='Train')
ax[0].plot(CtestLoss,'o-',label='Test')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss (MSE)')
ax[0].set_title('Model loss')
ax[0].legend()

ax[1].plot(CtrainAcc,'s-',label='Train')
ax[1].plot(CtestAcc,'o-',label='Test')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Accuracy (%)')
ax[1].set_title(f'Final model train/test accuracy: {CtrainAcc[-1]:.2f}/{CtestAcc[-1]:.2f}%')
ax[1].legend()

plt.suptitle('Basic CNN on Fruits360 data',fontweight='bold',fontsize=14)
plt.show()
plt.savefig('Basic_CNN.png')

# %% [markdown]
# ### VGG16 Initial Training and Testing

# %%
vgg = models.vgg16(pretrained=True)
# Freeze all layers (final layer changed later)
for p in vgg.parameters():
    p.requires_grad = False
    
# change the final layer
vgg.classifier[6] = nn.Linear(vgg.classifier[6].in_features,131)
vgg
# Out:
# /Users/ruyuliu/anaconda3/envs/pytorchenv/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/ruyuliu/anaconda3/envs/pytorchenv/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=131, bias=True)
#   )
# )

# %%
lossfun = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(vgg.parameters(),lr=0.01,momentum=.9)

# %%
import time
start_time = time.time()


numepochs = 10

# initialize losses
VtrainLoss = torch.zeros(numepochs)
VtestLoss  = torch.zeros(numepochs)
VtrainAcc  = torch.zeros(numepochs)
VtestAcc   = torch.zeros(numepochs)
Vtrain_correct = []
Vtest_correct = []


# loop over epochs
for epochi in range(numepochs):

    
    # loop over training data batches
    vgg.train() # switch to train mode
    batchLoss = []
    batchAcc  = []
    Vtrn_corr = 0
    
    for b, (X,y) in enumerate(train_loader):
        
        b += 1
        # forward pass and loss
        yHat = vgg(X)
        loss = lossfun(yHat,y)

        # backprop
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # loss and accuracy from this batch
        batchLoss.append(loss.item())
        batchAcc.append( torch.mean((torch.argmax(yHat,axis=1) == y).float()).item() )
        batch_corr = (torch.argmax(yHat,axis=1) == y).sum()
        Vtrn_corr += batch_corr 
        
        # Print interim results
        if b%50 == 0:
            print(f'epoch: {epochi:2}  batch: {b:4} loss: {loss.item():10.8f} train accuracy: {Vtrn_corr.item()*100/(100*b):7.3f}%')

      # end of batch loop...

    # and get average losses and accuracies across the batches
    VtrainLoss[epochi] = np.mean(batchLoss)
    VtrainAcc[epochi]  = 100*np.mean(batchAcc)

    
    #### test performance (here done in batches!)
    vgg.eval() # switch to test mode
    batchAcc  = []
    batchLoss = []
    Vtst_corr = 0
    
    for b,(X,y) in enumerate(test_loader):
        # forward pass and loss
        with torch.no_grad():
            yHat = vgg(X)
            loss = lossfun(yHat,y)
            Vtst_corr += (torch.argmax(yHat,axis=1) == y).sum()
            
        # loss and accuracy from this batch
        batchLoss.append(loss.item())
        batchAcc.append( torch.mean((torch.argmax(yHat,axis=1) == y).float()).item() )
    # end of batch loop...

    
    # and get average losses and accuracies across the batches
    VtestLoss[epochi] = np.mean(batchLoss)
    VtestAcc[epochi]  = 100*np.mean(batchAcc)

    # print out a status update
    print(f'Finished epoch {epochi+1}/{numepochs}. Test accuracy = {VtestAcc[epochi]:.2f}%')

print(f'\nDuration: {time.time() - start_time:.0f} seconds') # print the time elapsed
# Out:
# epoch:  0  batch:   50 loss: 0.71655333 train accuracy:  52.920%
# epoch:  0  batch:  100 loss: 0.93254775 train accuracy:  64.280%
# epoch:  0  batch:  150 loss: 0.82309473 train accuracy:  69.413%
# epoch:  0  batch:  200 loss: 0.75968379 train accuracy:  72.370%
# epoch:  0  batch:  250 loss: 0.69364828 train accuracy:  74.364%
# epoch:  0  batch:  300 loss: 0.52294809 train accuracy:  76.043%
# epoch:  0  batch:  350 loss: 0.66087341 train accuracy:  77.286%
# epoch:  0  batch:  400 loss: 1.14944482 train accuracy:  78.237%
# epoch:  0  batch:  450 loss: 0.57483888 train accuracy:  79.053%
# epoch:  0  batch:  500 loss: 0.59763753 train accuracy:  79.850%
# epoch:  0  batch:  550 loss: 0.37575915 train accuracy:  80.551%
# epoch:  0  batch:  600 loss: 0.84785807 train accuracy:  81.070%
# epoch:  0  batch:  650 loss: 0.36997882 train accuracy:  81.578%
# Finished epoch 1/10. Test accuracy = 90.24%
# epoch:  1  batch:   50 loss: 0.47203168 train accuracy:  89.200%
# epoch:  1  batch:  100 loss: 0.39834675 train accuracy:  88.860%
# epoch:  1  batch:  150 loss: 0.27136064 train accuracy:  88.720%
# epoch:  1  batch:  200 loss: 0.52670479 train accuracy:  88.595%
# epoch:  1  batch:  250 loss: 0.37020656 train accuracy:  88.640%
# epoch:  1  batch:  300 loss: 0.33583611 train accuracy:  88.590%
# epoch:  1  batch:  350 loss: 0.42344555 train accuracy:  88.706%
# epoch:  1  batch:  400 loss: 0.47612289 train accuracy:  88.865%
# epoch:  1  batch:  450 loss: 0.75754517 train accuracy:  88.884%
# epoch:  1  batch:  500 loss: 0.46752465 train accuracy:  88.970%
# epoch:  1  batch:  550 loss: 0.29131800 train accuracy:  88.965%
# epoch:  1  batch:  600 loss: 0.61277956 train accuracy:  89.020%
# epoch:  1  batch:  650 loss: 0.41827771 train accuracy:  89.040%
# Finished epoch 2/10. Test accuracy = 92.10%
# epoch:  2  batch:   50 loss: 0.44050148 train accuracy:  90.400%
# epoch:  2  batch:  100 loss: 0.41722593 train accuracy:  90.370%
# epoch:  2  batch:  150 loss: 0.33731434 train accuracy:  90.160%
# epoch:  2  batch:  200 loss: 0.41491413 train accuracy:  90.100%
# epoch:  2  batch:  250 loss: 0.26579323 train accuracy:  90.212%
# epoch:  2  batch:  300 loss: 0.26034921 train accuracy:  90.350%
# epoch:  2  batch:  350 loss: 0.30960402 train accuracy:  90.357%
# epoch:  2  batch:  400 loss: 0.56825024 train accuracy:  90.410%
# epoch:  2  batch:  450 loss: 0.54601294 train accuracy:  90.542%
# epoch:  2  batch:  500 loss: 0.51860839 train accuracy:  90.552%
# epoch:  2  batch:  550 loss: 0.51768100 train accuracy:  90.576%
# epoch:  2  batch:  600 loss: 0.43893149 train accuracy:  90.612%
# epoch:  2  batch:  650 loss: 0.14598775 train accuracy:  90.725%
# Finished epoch 3/10. Test accuracy = 92.33%
# epoch:  3  batch:   50 loss: 0.22369911 train accuracy:  91.480%
# epoch:  3  batch:  100 loss: 0.47123528 train accuracy:  91.240%
# epoch:  3  batch:  150 loss: 0.09782906 train accuracy:  91.367%
# epoch:  3  batch:  200 loss: 0.51178259 train accuracy:  91.465%
# epoch:  3  batch:  250 loss: 0.84599608 train accuracy:  91.384%
# epoch:  3  batch:  300 loss: 0.51234955 train accuracy:  91.347%
# epoch:  3  batch:  350 loss: 0.57481873 train accuracy:  91.457%
# epoch:  3  batch:  400 loss: 0.28576866 train accuracy:  91.520%
# epoch:  3  batch:  450 loss: 0.33379689 train accuracy:  91.527%
# epoch:  3  batch:  500 loss: 0.65100420 train accuracy:  91.534%
# epoch:  3  batch:  550 loss: 0.38369572 train accuracy:  91.558%
# epoch:  3  batch:  600 loss: 0.30582589 train accuracy:  91.568%
# epoch:  3  batch:  650 loss: 0.29798853 train accuracy:  91.580%
# Finished epoch 4/10. Test accuracy = 93.15%
# epoch:  4  batch:   50 loss: 0.64149356 train accuracy:  91.660%
# epoch:  4  batch:  100 loss: 0.35341778 train accuracy:  92.100%
# epoch:  4  batch:  150 loss: 0.26339209 train accuracy:  91.880%
# epoch:  4  batch:  200 loss: 0.37488881 train accuracy:  91.990%
# epoch:  4  batch:  250 loss: 0.37361565 train accuracy:  92.024%
# epoch:  4  batch:  300 loss: 0.59390116 train accuracy:  92.130%
# epoch:  4  batch:  350 loss: 0.56646067 train accuracy:  92.137%
# epoch:  4  batch:  400 loss: 0.47628444 train accuracy:  92.165%
# epoch:  4  batch:  450 loss: 0.37038887 train accuracy:  92.253%
# epoch:  4  batch:  500 loss: 0.25894848 train accuracy:  92.330%
# epoch:  4  batch:  550 loss: 0.59266162 train accuracy:  92.382%
# epoch:  4  batch:  600 loss: 0.57911426 train accuracy:  92.295%
# epoch:  4  batch:  650 loss: 0.28606230 train accuracy:  92.254%
# Finished epoch 5/10. Test accuracy = 92.53%
# epoch:  5  batch:   50 loss: 0.21841143 train accuracy:  92.600%
# epoch:  5  batch:  100 loss: 0.24756508 train accuracy:  92.650%
# epoch:  5  batch:  150 loss: 0.38876277 train accuracy:  92.573%
# epoch:  5  batch:  200 loss: 0.30597872 train accuracy:  92.505%
# epoch:  5  batch:  250 loss: 0.25910434 train accuracy:  92.504%
# epoch:  5  batch:  300 loss: 0.37255561 train accuracy:  92.563%
# epoch:  5  batch:  350 loss: 0.24757133 train accuracy:  92.654%
# epoch:  5  batch:  400 loss: 0.12181497 train accuracy:  92.638%
# epoch:  5  batch:  450 loss: 0.11989647 train accuracy:  92.636%
# epoch:  5  batch:  500 loss: 0.43939540 train accuracy:  92.630%
# epoch:  5  batch:  550 loss: 0.24006358 train accuracy:  92.665%
# epoch:  5  batch:  600 loss: 0.51361293 train accuracy:  92.642%
# epoch:  5  batch:  650 loss: 0.66951621 train accuracy:  92.642%
# Finished epoch 6/10. Test accuracy = 93.50%
# epoch:  6  batch:   50 loss: 0.35077235 train accuracy:  92.760%
# epoch:  6  batch:  100 loss: 0.35579163 train accuracy:  92.800%
# epoch:  6  batch:  150 loss: 0.02573625 train accuracy:  93.027%
# epoch:  6  batch:  200 loss: 0.20896423 train accuracy:  92.800%
# epoch:  6  batch:  250 loss: 0.46932724 train accuracy:  92.880%
# epoch:  6  batch:  300 loss: 0.22095615 train accuracy:  92.933%
# epoch:  6  batch:  350 loss: 0.35753182 train accuracy:  92.889%
# epoch:  6  batch:  400 loss: 0.11275643 train accuracy:  92.897%
# epoch:  6  batch:  450 loss: 0.42197990 train accuracy:  92.944%
# epoch:  6  batch:  500 loss: 0.82316566 train accuracy:  92.924%
# epoch:  6  batch:  550 loss: 0.47754347 train accuracy:  92.962%
# epoch:  6  batch:  600 loss: 0.49098569 train accuracy:  92.965%
# epoch:  6  batch:  650 loss: 0.27173778 train accuracy:  92.925%
# Finished epoch 7/10. Test accuracy = 92.30%
# epoch:  7  batch:   50 loss: 0.19611031 train accuracy:  92.840%
# epoch:  7  batch:  100 loss: 0.36355263 train accuracy:  92.780%
# epoch:  7  batch:  150 loss: 0.25339308 train accuracy:  92.793%
# epoch:  7  batch:  200 loss: 0.12307245 train accuracy:  92.920%
# epoch:  7  batch:  250 loss: 0.32148305 train accuracy:  92.904%
# epoch:  7  batch:  300 loss: 0.25455588 train accuracy:  93.050%
# epoch:  7  batch:  350 loss: 0.44665268 train accuracy:  93.046%
# epoch:  7  batch:  400 loss: 0.68284136 train accuracy:  93.115%
# epoch:  7  batch:  450 loss: 0.18083203 train accuracy:  93.073%
# epoch:  7  batch:  500 loss: 0.22553831 train accuracy:  93.122%
# epoch:  7  batch:  550 loss: 0.34862953 train accuracy:  93.129%
# epoch:  7  batch:  600 loss: 0.74515784 train accuracy:  93.095%
# epoch:  7  batch:  650 loss: 0.41830841 train accuracy:  93.132%
# Finished epoch 8/10. Test accuracy = 93.52%
# epoch:  8  batch:   50 loss: 0.11951482 train accuracy:  92.980%
# epoch:  8  batch:  100 loss: 0.39929882 train accuracy:  93.220%
# epoch:  8  batch:  150 loss: 0.45159924 train accuracy:  93.240%
# epoch:  8  batch:  200 loss: 0.59608585 train accuracy:  93.250%
# epoch:  8  batch:  250 loss: 0.37673840 train accuracy:  93.368%
# epoch:  8  batch:  300 loss: 0.40025443 train accuracy:  93.477%
# epoch:  8  batch:  350 loss: 0.15557081 train accuracy:  93.514%
# epoch:  8  batch:  400 loss: 0.26357061 train accuracy:  93.513%
# epoch:  8  batch:  450 loss: 0.13406093 train accuracy:  93.531%
# epoch:  8  batch:  500 loss: 0.35093907 train accuracy:  93.560%
# epoch:  8  batch:  550 loss: 0.44355407 train accuracy:  93.558%
# epoch:  8  batch:  600 loss: 0.16471890 train accuracy:  93.563%
# epoch:  8  batch:  650 loss: 0.32022154 train accuracy:  93.582%
# Finished epoch 9/10. Test accuracy = 93.01%
# epoch:  9  batch:   50 loss: 0.18728325 train accuracy:  93.020%
# epoch:  9  batch:  100 loss: 0.14140669 train accuracy:  93.510%
# epoch:  9  batch:  150 loss: 0.40575817 train accuracy:  93.513%
# epoch:  9  batch:  200 loss: 0.34004536 train accuracy:  93.685%
# epoch:  9  batch:  250 loss: 0.30232930 train accuracy:  93.592%
# epoch:  9  batch:  300 loss: 0.30267918 train accuracy:  93.623%
# epoch:  9  batch:  350 loss: 0.48909381 train accuracy:  93.643%
# epoch:  9  batch:  400 loss: 0.25562853 train accuracy:  93.555%
# epoch:  9  batch:  450 loss: 0.55575204 train accuracy:  93.529%
# epoch:  9  batch:  500 loss: 0.08233268 train accuracy:  93.604%
# epoch:  9  batch:  550 loss: 0.48541820 train accuracy:  93.531%
# epoch:  9  batch:  600 loss: 0.33323982 train accuracy:  93.508%
# epoch:  9  batch:  650 loss: 0.39717376 train accuracy:  93.528%
# Finished epoch 10/10. Test accuracy = 93.82%
#
# Duration: 32494 seconds

# %%
torch.save(vgg.state_dict(), 'FRUITS-VGG-Model.pt')

# %%
fig,ax = plt.subplots(1,2,figsize=(16,5))

ax[0].plot(VtrainLoss,'s-',label='Train')
ax[0].plot(VtestLoss,'o-',label='Test')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss (MSE)')
ax[0].set_title('Model loss')
ax[0].legend()

ax[1].plot(VtrainAcc,'s-',label='Train')
ax[1].plot(VtestAcc,'o-',label='Test')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Accuracy (%)')
ax[1].set_title(f'Final model train/test accuracy: {VtrainAcc[-1]:.2f}/{VtestAcc[-1]:.2f}%')
ax[1].legend()

plt.suptitle('Pretrained VGG-16 on Fruits360 data',fontweight='bold',fontsize=14)
plt.show()
plt.savefig('FigureVGG.png')

# %% [markdown]
# ## ResNet34 Initial Training and Testing

# %%
# You can use the following instead. 
weights = torchvision.models.ResNet34_Weights.DEFAULT
resnet = torchvision.models.resnet34(weights=weights)

# let's inspect this network
resnet
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
# Freeze all layers (final layer changed later)
for p in resnet.parameters():
    p.requires_grad = False

# change the final layer
resnet.fc = nn.Linear(512,131)
resnet
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=131, bias=True)
# )

# %%
lossfun = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(resnet.parameters(),lr=0.01,momentum=.9)

# %%
import time
start_time = time.time()


numepochs = 10

# initialize losses
RtrainLoss = torch.zeros(numepochs)
RtestLoss  = torch.zeros(numepochs)
RtrainAcc  = torch.zeros(numepochs)
RtestAcc   = torch.zeros(numepochs)
Rtrain_correct = []
Rtest_correct = []


# loop over epochs
for epochi in range(numepochs):
    
    # loop over training data batches
    resnet.train() # switch to train mode
    batchLoss = []
    batchAcc  = []
    Rtrn_corr = 0
    
    for b, (X,y) in enumerate(train_loader):
        
        b += 1
        
        # forward pass and loss
        yHat = resnet(X)
        loss = lossfun(yHat,y)

        # backprop
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # loss and accuracy from this batch
        batchLoss.append(loss.item())
        batchAcc.append( torch.mean((torch.argmax(yHat,axis=1) == y).float()).item() )
        batch_corr = (torch.argmax(yHat,axis=1) == y).sum()
        Rtrn_corr += batch_corr 
        
        # Print interim results
        if b%50 == 0:
            print(f'epoch: {epochi:2}  batch: {b:4} loss: {loss.item():10.8f} train accuracy: {Rtrn_corr.item()*100/(100*b):7.3f}%')

      # end of batch loop...

    # and get average losses and accuracies across the batches
    RtrainLoss[epochi] = np.mean(batchLoss)
    RtrainAcc[epochi]  = 100*np.mean(batchAcc)

    
    #### test performance (here done in batches!)
    resnet.eval() # switch to test mode
    batchAcc  = []
    batchLoss = []
    Rtst_corr = 0
    
    for b,(X,y) in enumerate(test_loader):
        # forward pass and loss
        with torch.no_grad():
            yHat = resnet(X)
            loss = lossfun(yHat,y)
            Rtst_corr += (torch.argmax(yHat,axis=1) == y).sum()
            
        # loss and accuracy from this batch
        batchLoss.append(loss.item())
        batchAcc.append( torch.mean((torch.argmax(yHat,axis=1) == y).float()).item() )
    # end of batch loop...

    
    # and get average losses and accuracies across the batches
    RtestLoss[epochi] = np.mean(batchLoss)
    RtestAcc[epochi]  = 100*np.mean(batchAcc)

    # print out a status update
    print(f'Finished epoch {epochi+1}/{numepochs}. Test accuracy = {RtestAcc[epochi]:.2f}%')

print(f'\nDuration: {time.time() - start_time:.0f} seconds') # print the time elapsed
# Out:
# epoch:  0  batch:   50 loss: 1.19080448 train accuracy:  45.760%
# epoch:  0  batch:  100 loss: 0.37083256 train accuracy:  68.420%
# epoch:  0  batch:  150 loss: 0.29777589 train accuracy:  77.653%
# epoch:  0  batch:  200 loss: 0.24385934 train accuracy:  82.570%
# epoch:  0  batch:  250 loss: 0.20708308 train accuracy:  85.764%
# epoch:  0  batch:  300 loss: 0.19075382 train accuracy:  87.970%
# epoch:  0  batch:  350 loss: 0.14287367 train accuracy:  89.569%
# epoch:  0  batch:  400 loss: 0.12825060 train accuracy:  90.782%
# epoch:  0  batch:  450 loss: 0.08429048 train accuracy:  91.758%
# epoch:  0  batch:  500 loss: 0.05518046 train accuracy:  92.524%
# epoch:  0  batch:  550 loss: 0.09672737 train accuracy:  93.155%
# epoch:  0  batch:  600 loss: 0.07024403 train accuracy:  93.683%
# epoch:  0  batch:  650 loss: 0.06127246 train accuracy:  94.151%
# Finished epoch 1/10. Test accuracy = 95.58%
# epoch:  1  batch:   50 loss: 0.08151577 train accuracy:  99.600%
# epoch:  1  batch:  100 loss: 0.08192253 train accuracy:  99.680%
# epoch:  1  batch:  150 loss: 0.05905532 train accuracy:  99.713%
# epoch:  1  batch:  200 loss: 0.04763788 train accuracy:  99.735%
# epoch:  1  batch:  250 loss: 0.02708221 train accuracy:  99.748%
# epoch:  1  batch:  300 loss: 0.04996429 train accuracy:  99.773%
# epoch:  1  batch:  350 loss: 0.05702373 train accuracy:  99.769%
# epoch:  1  batch:  400 loss: 0.04791190 train accuracy:  99.782%
# epoch:  1  batch:  450 loss: 0.03544747 train accuracy:  99.789%
# epoch:  1  batch:  500 loss: 0.05300518 train accuracy:  99.788%
# epoch:  1  batch:  550 loss: 0.04076958 train accuracy:  99.793%
# epoch:  1  batch:  600 loss: 0.05189291 train accuracy:  99.793%
# epoch:  1  batch:  650 loss: 0.02506086 train accuracy:  99.798%
# Finished epoch 2/10. Test accuracy = 96.54%
# epoch:  2  batch:   50 loss: 0.04198925 train accuracy:  99.940%
# epoch:  2  batch:  100 loss: 0.02569165 train accuracy:  99.960%
# epoch:  2  batch:  150 loss: 0.05912335 train accuracy:  99.927%
# epoch:  2  batch:  200 loss: 0.03281841 train accuracy:  99.920%
# epoch:  2  batch:  250 loss: 0.04844271 train accuracy:  99.924%
# epoch:  2  batch:  300 loss: 0.03945902 train accuracy:  99.923%
# epoch:  2  batch:  350 loss: 0.02433788 train accuracy:  99.917%
# epoch:  2  batch:  400 loss: 0.02107073 train accuracy:  99.918%
# epoch:  2  batch:  450 loss: 0.02828550 train accuracy:  99.922%
# epoch:  2  batch:  500 loss: 0.02672735 train accuracy:  99.926%
# epoch:  2  batch:  550 loss: 0.02285748 train accuracy:  99.931%
# epoch:  2  batch:  600 loss: 0.02749023 train accuracy:  99.928%
# epoch:  2  batch:  650 loss: 0.03172574 train accuracy:  99.928%
# Finished epoch 3/10. Test accuracy = 96.81%
# epoch:  3  batch:   50 loss: 0.02275505 train accuracy:  99.940%
# epoch:  3  batch:  100 loss: 0.03323871 train accuracy:  99.900%
# epoch:  3  batch:  150 loss: 0.02090460 train accuracy:  99.900%
# epoch:  3  batch:  200 loss: 0.02189137 train accuracy:  99.915%
# epoch:  3  batch:  250 loss: 0.01751940 train accuracy:  99.920%
# epoch:  3  batch:  300 loss: 0.02129723 train accuracy:  99.920%
# epoch:  3  batch:  350 loss: 0.02483371 train accuracy:  99.929%
# epoch:  3  batch:  400 loss: 0.02036610 train accuracy:  99.925%
# epoch:  3  batch:  450 loss: 0.01994215 train accuracy:  99.922%
# epoch:  3  batch:  500 loss: 0.02974116 train accuracy:  99.922%
# epoch:  3  batch:  550 loss: 0.01868536 train accuracy:  99.924%
# epoch:  3  batch:  600 loss: 0.01575338 train accuracy:  99.928%
# epoch:  3  batch:  650 loss: 0.01773477 train accuracy:  99.931%
# Finished epoch 4/10. Test accuracy = 96.93%
# epoch:  4  batch:   50 loss: 0.01368624 train accuracy:  99.960%
# epoch:  4  batch:  100 loss: 0.01735931 train accuracy:  99.970%
# epoch:  4  batch:  150 loss: 0.02364764 train accuracy:  99.967%
# epoch:  4  batch:  200 loss: 0.01875443 train accuracy:  99.975%
# epoch:  4  batch:  250 loss: 0.01820642 train accuracy:  99.976%
# epoch:  4  batch:  300 loss: 0.03180066 train accuracy:  99.973%
# epoch:  4  batch:  350 loss: 0.01415537 train accuracy:  99.969%
# epoch:  4  batch:  400 loss: 0.01119274 train accuracy:  99.970%
# epoch:  4  batch:  450 loss: 0.00974477 train accuracy:  99.971%
# epoch:  4  batch:  500 loss: 0.01688749 train accuracy:  99.972%
# epoch:  4  batch:  550 loss: 0.01270535 train accuracy:  99.973%
# epoch:  4  batch:  600 loss: 0.02476653 train accuracy:  99.972%
# epoch:  4  batch:  650 loss: 0.02624572 train accuracy:  99.972%
# Finished epoch 5/10. Test accuracy = 97.28%
# epoch:  5  batch:   50 loss: 0.02251484 train accuracy:  99.960%
# epoch:  5  batch:  100 loss: 0.01088157 train accuracy:  99.980%
# epoch:  5  batch:  150 loss: 0.01978271 train accuracy:  99.980%
# epoch:  5  batch:  200 loss: 0.01549766 train accuracy:  99.980%
# epoch:  5  batch:  250 loss: 0.01840005 train accuracy:  99.976%
# epoch:  5  batch:  300 loss: 0.01404710 train accuracy:  99.980%
# epoch:  5  batch:  350 loss: 0.01842264 train accuracy:  99.974%
# epoch:  5  batch:  400 loss: 0.02348895 train accuracy:  99.972%
# epoch:  5  batch:  450 loss: 0.00858320 train accuracy:  99.971%
# epoch:  5  batch:  500 loss: 0.01018149 train accuracy:  99.966%
# epoch:  5  batch:  550 loss: 0.01446698 train accuracy:  99.969%
# epoch:  5  batch:  600 loss: 0.00840285 train accuracy:  99.970%
# epoch:  5  batch:  650 loss: 0.01482579 train accuracy:  99.969%
# Finished epoch 6/10. Test accuracy = 97.33%
# epoch:  6  batch:   50 loss: 0.00764098 train accuracy:  99.900%
# epoch:  6  batch:  100 loss: 0.01246539 train accuracy:  99.950%
# epoch:  6  batch:  150 loss: 0.01260762 train accuracy:  99.953%
# epoch:  6  batch:  200 loss: 0.00695349 train accuracy:  99.960%
# epoch:  6  batch:  250 loss: 0.01327991 train accuracy:  99.964%
# epoch:  6  batch:  300 loss: 0.00951951 train accuracy:  99.963%
# epoch:  6  batch:  350 loss: 0.00635973 train accuracy:  99.966%
# epoch:  6  batch:  400 loss: 0.00639924 train accuracy:  99.970%
# epoch:  6  batch:  450 loss: 0.01269291 train accuracy:  99.971%
# epoch:  6  batch:  500 loss: 0.01407121 train accuracy:  99.974%
# epoch:  6  batch:  550 loss: 0.01267135 train accuracy:  99.973%
# epoch:  6  batch:  600 loss: 0.01246873 train accuracy:  99.972%
# epoch:  6  batch:  650 loss: 0.01618909 train accuracy:  99.974%
# Finished epoch 7/10. Test accuracy = 97.22%
# epoch:  7  batch:   50 loss: 0.02237491 train accuracy:  99.980%
# epoch:  7  batch:  100 loss: 0.00981222 train accuracy:  99.990%
# epoch:  7  batch:  150 loss: 0.02055311 train accuracy:  99.993%
# epoch:  7  batch:  200 loss: 0.00866861 train accuracy:  99.995%
# epoch:  7  batch:  250 loss: 0.00906267 train accuracy:  99.988%
# epoch:  7  batch:  300 loss: 0.00843992 train accuracy:  99.987%
# epoch:  7  batch:  350 loss: 0.01803415 train accuracy:  99.986%
# epoch:  7  batch:  400 loss: 0.01505983 train accuracy:  99.983%
# epoch:  7  batch:  450 loss: 0.00864371 train accuracy:  99.984%
# epoch:  7  batch:  500 loss: 0.00885806 train accuracy:  99.986%
# epoch:  7  batch:  550 loss: 0.01220527 train accuracy:  99.987%
# epoch:  7  batch:  600 loss: 0.01071047 train accuracy:  99.985%
# epoch:  7  batch:  650 loss: 0.01413958 train accuracy:  99.983%
# Finished epoch 8/10. Test accuracy = 97.46%
# epoch:  8  batch:   50 loss: 0.01369094 train accuracy: 100.000%
# epoch:  8  batch:  100 loss: 0.00886222 train accuracy:  99.990%
# epoch:  8  batch:  150 loss: 0.00816418 train accuracy:  99.993%
# epoch:  8  batch:  200 loss: 0.00860932 train accuracy:  99.995%
# epoch:  8  batch:  250 loss: 0.00531687 train accuracy:  99.992%
# epoch:  8  batch:  300 loss: 0.00606694 train accuracy:  99.990%
# epoch:  8  batch:  350 loss: 0.00935302 train accuracy:  99.989%
# epoch:  8  batch:  400 loss: 0.00975015 train accuracy:  99.990%
# epoch:  8  batch:  450 loss: 0.01620161 train accuracy:  99.989%
# epoch:  8  batch:  500 loss: 0.00646447 train accuracy:  99.990%
# epoch:  8  batch:  550 loss: 0.00787135 train accuracy:  99.989%
# epoch:  8  batch:  600 loss: 0.00747822 train accuracy:  99.988%
# epoch:  8  batch:  650 loss: 0.01068997 train accuracy:  99.988%
# Finished epoch 9/10. Test accuracy = 97.53%
# epoch:  9  batch:   50 loss: 0.01256151 train accuracy: 100.000%
# epoch:  9  batch:  100 loss: 0.01607242 train accuracy:  99.980%
# epoch:  9  batch:  150 loss: 0.01158394 train accuracy:  99.980%
# epoch:  9  batch:  200 loss: 0.01563005 train accuracy:  99.985%
# epoch:  9  batch:  250 loss: 0.00668588 train accuracy:  99.984%
# epoch:  9  batch:  300 loss: 0.00662065 train accuracy:  99.980%
# epoch:  9  batch:  350 loss: 0.01224473 train accuracy:  99.980%
# epoch:  9  batch:  400 loss: 0.00772056 train accuracy:  99.978%
# epoch:  9  batch:  450 loss: 0.00436659 train accuracy:  99.976%
# epoch:  9  batch:  500 loss: 0.00818152 train accuracy:  99.976%
# epoch:  9  batch:  550 loss: 0.00685170 train accuracy:  99.978%
# epoch:  9  batch:  600 loss: 0.00837599 train accuracy:  99.980%
# epoch:  9  batch:  650 loss: 0.00780313 train accuracy:  99.978%
# Finished epoch 10/10. Test accuracy = 97.45%
#
# Duration: 43001 seconds

# %%
torch.save(resnet.state_dict(), 'FRUITS-RESNET34-Model.pt')

# %%
fig,ax = plt.subplots(1,2,figsize=(16,5))

ax[0].plot(RtrainLoss,'s-',label='Train')
ax[0].plot(RtestLoss,'o-',label='Test')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss (MSE)')
ax[0].set_title('Model loss')
ax[0].legend()

ax[1].plot(RtrainAcc,'s-',label='Train')
ax[1].plot(RtestAcc,'o-',label='Test')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Accuracy (%)')
ax[1].set_title(f'Final model train/test accuracy: {RtrainAcc[-1]:.2f}/{RtestAcc[-1]:.2f}%')
ax[1].legend()

plt.suptitle('Pretrained ResNet-34 on Fruits360 data',fontweight='bold',fontsize=14)
plt.show()
plt.savefig('FigureResnet34.png')

# %% [markdown]
# ## ResNet50 Initial Training and Testing

# %%
# You can use the following instead. 
weights = torchvision.models.ResNet50_Weights.DEFAULT
resnet = torchvision.models.resnet50(weights=weights)

# let's inspect this network
resnet
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
# Freeze all layers (final layer changed later)
for p in resnet.parameters():
    p.requires_grad = False

# change the final layer
resnet.fc = nn.Linear(2048,131)
resnet
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=131, bias=True)
# )

# %%
lossfun = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(resnet.parameters(),lr=0.01,momentum=.9)

# %%
import time
start_time = time.time()


numepochs = 10

# initialize losses
RtrainLoss = torch.zeros(numepochs)
RtestLoss  = torch.zeros(numepochs)
RtrainAcc  = torch.zeros(numepochs)
RtestAcc   = torch.zeros(numepochs)
Rtrain_correct = []
Rtest_correct = []


# loop over epochs
for epochi in range(numepochs):
    
    # loop over training data batches
    resnet.train() # switch to train mode
    batchLoss = []
    batchAcc  = []
    Rtrn_corr = 0
    
    for b, (X,y) in enumerate(train_loader):
        
        b += 1
        
        # forward pass and loss
        yHat = resnet(X)
        loss = lossfun(yHat,y)

        # backprop
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # loss and accuracy from this batch
        batchLoss.append(loss.item())
        batchAcc.append( torch.mean((torch.argmax(yHat,axis=1) == y).float()).item() )
        batch_corr = (torch.argmax(yHat,axis=1) == y).sum()
        Rtrn_corr += batch_corr 
        
        # Print interim results
        if b%50 == 0:
            print(f'epoch: {epochi:2}  batch: {b:4} loss: {loss.item():10.8f} train accuracy: {Rtrn_corr.item()*100/(100*b):7.3f}%')

      # end of batch loop...

    # and get average losses and accuracies across the batches
    RtrainLoss[epochi] = np.mean(batchLoss)
    RtrainAcc[epochi]  = 100*np.mean(batchAcc)

    
    #### test performance (here done in batches!)
    resnet.eval() # switch to test mode
    batchAcc  = []
    batchLoss = []
    Rtst_corr = 0
    
    for b,(X,y) in enumerate(test_loader):
        # forward pass and loss
        with torch.no_grad():
            yHat = resnet(X)
            loss = lossfun(yHat,y)
            Rtst_corr += (torch.argmax(yHat,axis=1) == y).sum()
            
        # loss and accuracy from this batch
        batchLoss.append(loss.item())
        batchAcc.append( torch.mean((torch.argmax(yHat,axis=1) == y).float()).item() )
    # end of batch loop...

    
    # and get average losses and accuracies across the batches
    RtestLoss[epochi] = np.mean(batchLoss)
    RtestAcc[epochi]  = 100*np.mean(batchAcc)

    # print out a status update
    print(f'Finished epoch {epochi+1}/{numepochs}. Test accuracy = {RtestAcc[epochi]:.2f}%')

print(f'\nDuration: {time.time() - start_time:.0f} seconds') # print the time elapsed
# Out:
# epoch:  0  batch:   50 loss: 3.17477489 train accuracy:  33.400%
# epoch:  0  batch:  100 loss: 1.97480285 train accuracy:  54.890%
# epoch:  0  batch:  150 loss: 1.65920377 train accuracy:  65.867%
# epoch:  0  batch:  200 loss: 1.01481962 train accuracy:  72.680%
# epoch:  0  batch:  250 loss: 0.72968584 train accuracy:  77.160%
# epoch:  0  batch:  300 loss: 0.69319463 train accuracy:  80.420%
# epoch:  0  batch:  350 loss: 0.55368900 train accuracy:  82.703%
# epoch:  0  batch:  400 loss: 0.47081566 train accuracy:  84.552%
# epoch:  0  batch:  450 loss: 0.39100769 train accuracy:  85.984%
# epoch:  0  batch:  500 loss: 0.26135913 train accuracy:  87.170%
# epoch:  0  batch:  550 loss: 0.37485254 train accuracy:  88.184%
# epoch:  0  batch:  600 loss: 0.31195500 train accuracy:  89.058%
# epoch:  0  batch:  650 loss: 0.19612449 train accuracy:  89.791%
# Finished epoch 1/10. Test accuracy = 92.87%
# epoch:  1  batch:   50 loss: 0.23251846 train accuracy:  98.540%
# epoch:  1  batch:  100 loss: 0.16170046 train accuracy:  98.800%
# epoch:  1  batch:  150 loss: 0.19968587 train accuracy:  98.793%
# epoch:  1  batch:  200 loss: 0.16378105 train accuracy:  98.905%
# epoch:  1  batch:  250 loss: 0.14675888 train accuracy:  98.952%
# epoch:  1  batch:  300 loss: 0.10954655 train accuracy:  98.990%
# epoch:  1  batch:  350 loss: 0.13817057 train accuracy:  99.006%
# epoch:  1  batch:  400 loss: 0.10395732 train accuracy:  99.058%
# epoch:  1  batch:  450 loss: 0.16400498 train accuracy:  99.080%
# epoch:  1  batch:  500 loss: 0.24755922 train accuracy:  99.118%
# epoch:  1  batch:  550 loss: 0.13772731 train accuracy:  99.145%
# epoch:  1  batch:  600 loss: 0.15426381 train accuracy:  99.172%
# epoch:  1  batch:  650 loss: 0.22412206 train accuracy:  99.203%
# Finished epoch 2/10. Test accuracy = 94.61%
# epoch:  2  batch:   50 loss: 0.24447092 train accuracy:  99.400%
# epoch:  2  batch:  100 loss: 0.10519410 train accuracy:  99.510%
# epoch:  2  batch:  150 loss: 0.09057903 train accuracy:  99.520%
# epoch:  2  batch:  200 loss: 0.09342282 train accuracy:  99.550%
# epoch:  2  batch:  250 loss: 0.08038220 train accuracy:  99.556%
# epoch:  2  batch:  300 loss: 0.08246097 train accuracy:  99.550%
# epoch:  2  batch:  350 loss: 0.08017183 train accuracy:  99.557%
# epoch:  2  batch:  400 loss: 0.04418276 train accuracy:  99.575%
# epoch:  2  batch:  450 loss: 0.09139317 train accuracy:  99.593%
# epoch:  2  batch:  500 loss: 0.07419644 train accuracy:  99.602%
# epoch:  2  batch:  550 loss: 0.10673891 train accuracy:  99.616%
# epoch:  2  batch:  600 loss: 0.07637914 train accuracy:  99.612%
# epoch:  2  batch:  650 loss: 0.10994915 train accuracy:  99.618%
# Finished epoch 3/10. Test accuracy = 94.95%
# epoch:  3  batch:   50 loss: 0.14557216 train accuracy:  99.620%
# epoch:  3  batch:  100 loss: 0.12770763 train accuracy:  99.720%
# epoch:  3  batch:  150 loss: 0.13229379 train accuracy:  99.707%
# epoch:  3  batch:  200 loss: 0.07635321 train accuracy:  99.720%
# epoch:  3  batch:  250 loss: 0.05315752 train accuracy:  99.704%
# epoch:  3  batch:  300 loss: 0.05212979 train accuracy:  99.727%
# epoch:  3  batch:  350 loss: 0.04116585 train accuracy:  99.700%
# epoch:  3  batch:  400 loss: 0.07432640 train accuracy:  99.707%
# epoch:  3  batch:  450 loss: 0.05270782 train accuracy:  99.711%
# epoch:  3  batch:  500 loss: 0.09270062 train accuracy:  99.712%
# epoch:  3  batch:  550 loss: 0.09010113 train accuracy:  99.711%
# epoch:  3  batch:  600 loss: 0.05265948 train accuracy:  99.717%
# epoch:  3  batch:  650 loss: 0.05914787 train accuracy:  99.723%
# Finished epoch 4/10. Test accuracy = 95.54%
# epoch:  4  batch:   50 loss: 0.04984372 train accuracy:  99.780%
# epoch:  4  batch:  100 loss: 0.05512105 train accuracy:  99.790%
# epoch:  4  batch:  150 loss: 0.08122113 train accuracy:  99.787%
# epoch:  4  batch:  200 loss: 0.06666640 train accuracy:  99.800%
# epoch:  4  batch:  250 loss: 0.09513560 train accuracy:  99.780%
# epoch:  4  batch:  300 loss: 0.10274079 train accuracy:  99.763%
# epoch:  4  batch:  350 loss: 0.05302646 train accuracy:  99.769%
# epoch:  4  batch:  400 loss: 0.05725252 train accuracy:  99.780%
# epoch:  4  batch:  450 loss: 0.09259748 train accuracy:  99.789%
# epoch:  4  batch:  500 loss: 0.08265754 train accuracy:  99.796%
# epoch:  4  batch:  550 loss: 0.07783351 train accuracy:  99.798%
# epoch:  4  batch:  600 loss: 0.05352985 train accuracy:  99.793%
# epoch:  4  batch:  650 loss: 0.02915210 train accuracy:  99.797%
# Finished epoch 5/10. Test accuracy = 95.89%
# epoch:  5  batch:   50 loss: 0.05070666 train accuracy:  99.800%
# epoch:  5  batch:  100 loss: 0.09702995 train accuracy:  99.790%
# epoch:  5  batch:  150 loss: 0.04146737 train accuracy:  99.813%
# epoch:  5  batch:  200 loss: 0.03765083 train accuracy:  99.810%
# epoch:  5  batch:  250 loss: 0.09569722 train accuracy:  99.792%
# epoch:  5  batch:  300 loss: 0.03786911 train accuracy:  99.793%
# epoch:  5  batch:  350 loss: 0.04117224 train accuracy:  99.794%
# epoch:  5  batch:  400 loss: 0.03744812 train accuracy:  99.815%
# epoch:  5  batch:  450 loss: 0.04165837 train accuracy:  99.822%
# epoch:  5  batch:  500 loss: 0.05140577 train accuracy:  99.818%
# epoch:  5  batch:  550 loss: 0.03189845 train accuracy:  99.822%
# epoch:  5  batch:  600 loss: 0.05904284 train accuracy:  99.818%
# epoch:  5  batch:  650 loss: 0.03832237 train accuracy:  99.815%
# Finished epoch 6/10. Test accuracy = 96.12%
# epoch:  6  batch:   50 loss: 0.05351852 train accuracy:  99.860%
# epoch:  6  batch:  100 loss: 0.04849672 train accuracy:  99.870%
# epoch:  6  batch:  150 loss: 0.02515500 train accuracy:  99.873%
# epoch:  6  batch:  200 loss: 0.04118936 train accuracy:  99.875%
# epoch:  6  batch:  250 loss: 0.04988355 train accuracy:  99.876%
# epoch:  6  batch:  300 loss: 0.02775580 train accuracy:  99.877%
# epoch:  6  batch:  350 loss: 0.08253415 train accuracy:  99.883%
# epoch:  6  batch:  400 loss: 0.08249760 train accuracy:  99.877%
# epoch:  6  batch:  450 loss: 0.04238112 train accuracy:  99.876%
# epoch:  6  batch:  500 loss: 0.02482505 train accuracy:  99.886%
# epoch:  6  batch:  550 loss: 0.02056117 train accuracy:  99.885%
# epoch:  6  batch:  600 loss: 0.02153086 train accuracy:  99.883%
# epoch:  6  batch:  650 loss: 0.04666502 train accuracy:  99.885%
# Finished epoch 7/10. Test accuracy = 96.26%
# epoch:  7  batch:   50 loss: 0.02334356 train accuracy:  99.920%
# epoch:  7  batch:  100 loss: 0.02721244 train accuracy:  99.920%
# epoch:  7  batch:  150 loss: 0.06850035 train accuracy:  99.907%
# epoch:  7  batch:  200 loss: 0.04864058 train accuracy:  99.895%
# epoch:  7  batch:  250 loss: 0.04254078 train accuracy:  99.884%
# epoch:  7  batch:  300 loss: 0.03915140 train accuracy:  99.880%
# epoch:  7  batch:  350 loss: 0.02351395 train accuracy:  99.889%
# epoch:  7  batch:  400 loss: 0.02874102 train accuracy:  99.892%
# epoch:  7  batch:  450 loss: 0.02742249 train accuracy:  99.896%
# epoch:  7  batch:  500 loss: 0.02427186 train accuracy:  99.896%
# epoch:  7  batch:  550 loss: 0.03854416 train accuracy:  99.904%
# epoch:  7  batch:  600 loss: 0.02064575 train accuracy:  99.898%
# epoch:  7  batch:  650 loss: 0.02574394 train accuracy:  99.898%
# Finished epoch 8/10. Test accuracy = 96.37%
# epoch:  8  batch:   50 loss: 0.02353798 train accuracy:  99.940%
# epoch:  8  batch:  100 loss: 0.01764845 train accuracy:  99.930%
# epoch:  8  batch:  150 loss: 0.02305336 train accuracy:  99.933%
# epoch:  8  batch:  200 loss: 0.02007272 train accuracy:  99.930%
# epoch:  8  batch:  250 loss: 0.01450701 train accuracy:  99.936%
# epoch:  8  batch:  300 loss: 0.02344954 train accuracy:  99.927%
# epoch:  8  batch:  350 loss: 0.03253555 train accuracy:  99.920%
# epoch:  8  batch:  400 loss: 0.02533602 train accuracy:  99.918%
# epoch:  8  batch:  450 loss: 0.01913362 train accuracy:  99.913%
# epoch:  8  batch:  500 loss: 0.02179104 train accuracy:  99.908%
# epoch:  8  batch:  550 loss: 0.03196533 train accuracy:  99.907%
# epoch:  8  batch:  600 loss: 0.01364968 train accuracy:  99.910%
# epoch:  8  batch:  650 loss: 0.03326406 train accuracy:  99.909%
# Finished epoch 9/10. Test accuracy = 96.52%
# epoch:  9  batch:   50 loss: 0.04664513 train accuracy:  99.860%
# epoch:  9  batch:  100 loss: 0.05962653 train accuracy:  99.860%
# epoch:  9  batch:  150 loss: 0.05281179 train accuracy:  99.907%
# epoch:  9  batch:  200 loss: 0.02397192 train accuracy:  99.930%
# epoch:  9  batch:  250 loss: 0.07757893 train accuracy:  99.924%
# epoch:  9  batch:  300 loss: 0.05380687 train accuracy:  99.923%
# epoch:  9  batch:  350 loss: 0.02601326 train accuracy:  99.920%
# epoch:  9  batch:  400 loss: 0.04793410 train accuracy:  99.920%
# epoch:  9  batch:  450 loss: 0.02096171 train accuracy:  99.922%
# epoch:  9  batch:  500 loss: 0.02214580 train accuracy:  99.916%
# epoch:  9  batch:  550 loss: 0.04711604 train accuracy:  99.909%
# epoch:  9  batch:  600 loss: 0.04161212 train accuracy:  99.910%
# epoch:  9  batch:  650 loss: 0.01990322 train accuracy:  99.905%
# Finished epoch 10/10. Test accuracy = 96.55%
#
# Duration: 72954 seconds

# %%
torch.save(resnet.state_dict(), 'FRUITS-RESNET-Model.pt')

# %%
fig,ax = plt.subplots(1,2,figsize=(16,5))

ax[0].plot(RtrainLoss,'s-',label='Train')
ax[0].plot(RtestLoss,'o-',label='Test')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss (MSE)')
ax[0].set_title('Model loss')
ax[0].legend()

ax[1].plot(RtrainAcc,'s-',label='Train')
ax[1].plot(RtestAcc,'o-',label='Test')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Accuracy (%)')
ax[1].set_title(f'Final model train/test accuracy: {RtrainAcc[-1]:.2f}/{RtestAcc[-1]:.2f}%')
ax[1].legend()

plt.suptitle('Pretrained ResNet-50 on Fruits360 data',fontweight='bold',fontsize=14)
plt.show()
plt.savefig('FigureResnet.png')
